# %% [markdown]
# # OmniBrain Studio Walkthrough

# %%
from backend.agents.supervisor import SupervisorOrchestrator
orchestrator = SupervisorOrchestrator()
state = orchestrator.process_query('What was NVIDIA quarterly revenue?')
print(state.synthesized_memo)
